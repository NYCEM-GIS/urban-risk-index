# %% [markdown]
# # Preprocessing - Estimated Annual Loss

# %% [markdown]
# ## Settings

# %%
import URI.UTILITY.utils_1 as utils
import warnings
import datetime
utils.set_home()
warnings.filterwarnings(action='ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

#define hazards to run
run_all = True
run_CER = True          # coastal erosion
run_CSF = True          # coastal flooding
run_CSW = True          # coastal winds
run_ERQ = True          # earthquake
run_EXH = True          # extreme heat
run_WIW = True          # winter weather
run_normalization = True    # normalization factors (not a hazard, but needs to be run!)

# %% [markdown]
# ## CER - Coastal Erosion

# %%
if (run_all or run_CER):
    
    print("{} Pre-processing CER ecosystem (environmental) loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_CER_ecosystem_loss_1.py
# Out:
# 12:08 Pre-processing CER ecosystem (environmental) loss.....
# Finished calculating CER ecosystem loss.

# %% [markdown]
# ## CSF - Coastal Flooding

# %%
if (run_all or run_CSF):
    
    print("{} Pre-processing CSF dislocation (indirect cost) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_CSF_dislocation_loss_2.py
    
    print("{} Pre-processing CSF building damage (property loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_CSF_hazus_loss_1.py

    print("{} Pre-processing CSF transportation losses (response cost) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_CSF_transportation_loss_1.py
# Out:
# 11:07 Pre-processing CSF dislocation (indirect cost) factor.....
# Finished calculating CSF dislocation loss.
# 11:07 Pre-processing CSF building damage (property loss) factor.....
# Finished calculating CSF Building Damage.
# 11:07 Pre-processing CSF transportation losses (response cost) factor.....
# Finished calculating CST Transportation loss.

# %% [markdown]
# # CSW - Coastal Winds

# %%
if (run_all or run_CSW):
    print("{} Pre-processing CSW building damage (property loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_CSW_hazus_loss_1.py

    print("{} Pre-processing CSW tree services (response cost) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_CSW_tree_loss_1.py
# Out:
# 12:09 Pre-processing CSW building damage (property loss) factor.....
# Finished calculating CSW Building Damage.
# 12:09 Pre-processing CSW tree services (response cost) factor.....
# Finished calculating CST loss due to tree servicing.

# %% [markdown]
# # ERQ - Earthquake

# %%
if (run_all or run_ERQ):

    print("{} Pre-processing ERQ bulding damage (property loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_ERQ_hazus_loss_1.py
# Out:
# 12:12 Pre-processing ERQ bulding damage (property loss) factor.....
# Finished calculating ERQ Building Damage.

# %% [markdown]
# # EXH - Extreme Heat

# %%
if (run_all or run_EXH):
    
    print("{} Pre-processing EXH power loss (indirect cost) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_EXH_power_loss_1.py

    print("{} Pre-processing EXH injury (morbidity loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_EXH_injury_loss_1.py
    
    print("{} Pre-processing EXH death (mortality loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_EXH_death_loss_1.py
# Out:
# 12:12 Pre-processing EXH power loss (indirect cost) factor.....
# Finished calculating ESL for extreme heat due to power outage.
# 12:12 Pre-processing EXH injury (morbidity loss) factor.....
# Finished calculating EXH injury loss.
# 12:12 Pre-processing EXH death (mortality loss) factor.....
# Finished calculating EXH loss due to excess deaths.

# %% [markdown]
# # WIW - Winter Weather

# %%
if (run_all or run_WIW):
    
    print("{} Pre-processing WIW injury (morbidity loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_WIW_injury_loss_1.py

    print("{} Pre-processing WIW death (mortality loss) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_WIW_death_loss_1.py

    print("{} Pre-processing WIW snow removal (response cost) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_WIW_snow_loss_1.py

    print("{} Pre-processing WIW tree services (response cost) factor.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/ESL_WIW_tree_loss_1.py
# Out:
# 16:37 Pre-processing WIW injury (morbidity loss) factor.....
# Finished calculating WIW injury loss.
# 16:37 Pre-processing WIW death (mortality loss) factor.....
# Finished calculating WIW death loss.
# 16:37 Pre-processing WIW snow removal (response cost) factor.....
# Finished calculating  ESL WIW snow removal loss.
# 16:37 Pre-processing WIW tree services (response cost) factor.....
# Finished calculating WIW loss due to tree servicing.

# %% [markdown]
# # Normalization Factors

# %%
if (run_all or run_normalization):
    
    print("{} Pre-processing Normalization Factors.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/PRE_PROCESSING/write_normalization_vars_1.py
# Out:
# 12:14 Pre-processing Normalization Factors.....

# %%
print(f"Complete {datetime.datetime.now().strftime('%H:%M')}")
# Out:
# Complete 13:16
