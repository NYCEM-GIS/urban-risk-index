# %% [markdown]
# # Preprocessing - Estimated Annual Loss

# %% [markdown]
# ## Settings

# %%
import URI.MISC.utils_1 as utils
import URI.PARAMS.params as params
utils.set_home()
import warnings
import datetime
import os
warnings.filterwarnings(action='ignore')
warnings.simplefilter(action='ignore', category=FutureWarning)

#define hazards to run
run_all = True

run_CER = True          # coastal erosion
run_CRN = True          # chemical, biological, radiological, nuclear
run_CST = True          # coastal storms, flooding, and high winds (grouped)
run_CYB = True          # cyber threat
run_EMG = True          # emerging diseases
run_ERQ = True          # earthquake
run_EXH = True          # extreme heat
run_RES = True          # respiratory disease
run_WIW = True          # winter weather
run_normalize = True    # normalization factors (not a hazard, but needs to be run!)

# %% [markdown]
# ## 1. Coastal Erosion

# %%
if (run_all or run_CER):
    
    print("{} Pre-processing CER ecosystem loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CER_ecosystem_loss_1.py
# Out:
# 15:13 Pre-processing CER ecosystem loss.....
# Finished calculating CER ecosystem loss.

# %% [markdown]
# ## 2. Chemical, Biological, Radiological, and Nuclear

# %%
if (run_all or run_CRN):

    print("{} Pre-processing CRN death loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CRN_death_loss_1.py

    print("{} Pre-processing CRN injury loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CRN_injury_loss_1.py
# Out:
# 15:13 Pre-processing CRN death loss.....
# Finished calculating CRN loss due to deaths.
# 15:13 Pre-processing CRN injury loss.....
# Finished calculating CRN loss due to injury.

# %% [markdown]
# ## 3. Coastal Storms, Flooding, and High Winds

# %%
if (run_all or run_CST):
    
    print("{} Pre-processing FLD/CST flood property loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_FLD_hazus_loss_1.py

    print("{} Pre-processing CST/HIW wind damage loss loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CST_hazus_loss_1.py

    print("{} Pre-processing CST death loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CST_death_loss_1.py

    print("{} Pre-processing CST/FLD flooding dislocation loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CST_dislocation_loss_1.py

    print("{} Pre-processing CST infrastructure repair loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CST_dot_loss_1.py

    print("{} Pre-processing CST tree service loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CST_tree_loss_1.py
# Out:
# 15:13 Pre-processing FLD/CST flood property loss.....
# Finished calculating FLD Hazus loss.
# 15:13 Pre-processing CST/HIW wind damage loss loss.....
# Finished calculating CST Hazus loss.
# 15:13 Pre-processing CST death loss.....
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\arrays\datetimelike.py:983, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     982 try:
# --> 983     other = self._validate_comparison_value(other)
#     984 except InvalidComparison:
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\arrays\datetimelike.py:542, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     541 elif not is_list_like(other):
# --> 542     raise InvalidComparison(other)
#     544 elif len(other) != len(self):
#
# InvalidComparison: 2000-01-01
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File ~\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\4_CODE\URI\DATA_PROCESSING\ESL_CST_death_loss_1.py:49
#      47 df_storms_cst['StartDate'] = pd.to_datetime(df_storms_cst['StartDate'])
#      48 df_storms_cst['EndDate'] = pd.to_datetime(df_storms_cst['EndDate'])
# ---> 49 df_storms_cst = df_storms_cst.loc[df_storms_cst['StartDate']>start_date]
#      50 df_storms_cst = df_storms_cst.loc[df_storms_cst['EndDate']<end_date]
#      52 #%% count fatalities and injuries
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6119 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6121 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\ops\array_ops.py:330, in comparison_op(left, right, op)
#     321         raise ValueError(
#     322             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     323         )
#     325 if should_extension_dispatch(lvalues, rvalues) or (
#     326     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     327     and lvalues.dtype != object
#     328 ):
#     329     # Call the method on lvalues
# --> 330     res_values = op(lvalues, rvalues)
#     332 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     333     # numpy does not like comparisons vs None
#     334     if op is operator.ne:
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\arrays\datetimelike.py:985, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     983     other = self._validate_comparison_value(other)
#     984 except InvalidComparison:
# --> 985     return invalid_comparison(self, other, op)
#     987 dtype = getattr(other, "dtype", None)
#     988 if is_object_dtype(dtype):
#     989     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     990     #  comparison otherwise it would raise when comparing to None
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pandas\core\ops\invalid.py:40, in invalid_comparison(left, right, op)
#      38 else:
#      39     typ = type(right).__name__
# ---> 40     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      41 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and date
# 15:13 Pre-processing CST/FLD flooding dislocation loss.....
# Finished calculating CST dislocation Loss.
# 15:16 Pre-processing CST infrastructure repair loss.....
# Finished calculating CST DOT loss.
# 15:16 Pre-processing CST tree service loss.....
# Finished calculating CST loss due to tree servicing.

# %% [markdown]
# ## 4. Cyber Threat

# %%
if (run_all or run_CYB):
    
    print("{} Pre-processing CYB economic loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_CYB_econ_loss_1.py
# Out:
# 15:18 Pre-processing CYB economic loss.....
# Finished calculating CYB loss due to economic losses.

# %% [markdown]
# ## 5. Emerging Diseases

# %%
if (run_all or run_EMG):

    print("{} Pre-processing EMG death loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_EMG_loss_1.py
# Out:
# 15:18 Pre-processing EMG death loss.....
# Finished calculating EMG loss.

# %% [markdown]
# ## 6. Earthquake

# %%
if (run_all or run_ERQ):

    print("{} Pre-processing ERQ loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_ERQ_hazus_loss_1.py
# Out:
# 15:18 Pre-processing ERQ loss.....
# Finished calculating ERQ Hazus loss.

# %% [markdown]
# ## 7. Extreme Heat

# %%
if (run_all or run_EXH):
    
    print("{} Pre-processing EXH death loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_EXH_death_loss_1.py

    print("{} Pre-processing EXH injury loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_EXH_injury_loss_1.py

    print("{} Pre-processing EXH power outage loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_EXH_power_loss_1.py
# Out:
# 14:26 Pre-processing EXH death loss.....
# Finished calculating EXH loss due to excess deaths.
# 14:26 Pre-processing EXH injury loss.....
# Finished calculating EXH injury loss.
# 14:26 Pre-processing EXH power outage loss.....
# Finished calculating ESL for extreme heat due to power outage.

# %% [markdown]
# ## 8. Respiratory Diseases

# %%
if (run_all or run_RES):
    
    print("{} Pre-processing RES death and injury loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_RES_loss_1.py
# Out:
# 15:18 Pre-processing RES death and injury loss.....
# ---------------------------------------------------------------------------
# GEOSException                             Traceback (most recent call last)
# File ~\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\4_CODE\URI\DATA_PROCESSING\ESL_RES_loss_1.py:70
#      67 gdf_PVI['COMMDIST_area_sqmi'] = gdf_PVI.geometry.area/(5280.**2)
#      69 #%% get number of vulnerable people in each tract
# ---> 70 gdf_union = gpd.overlay(gdf_tracts, gdf_PVI, how='union')
#      71 # drop portions that don't overlap with tracts
#      72 gdf_union.dropna(subset=['BCT_txt'], inplace=True)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\geopandas\tools\overlay.py:325, in overlay(df1, df2, how, keep_geom_type, make_valid)
#     323     result = _overlay_symmetric_diff(df1, df2)
#     324 elif how == "union":
# --> 325     result = _overlay_union(df1, df2)
#     326 elif how == "identity":
#     327     dfunion = _overlay_union(df1, df2)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\geopandas\tools\overlay.py:141, in _overlay_union(df1, df2)
#     137 """
#     138 Overlay Union operation used in overlay function
#     139 """
#     140 dfinter = _overlay_intersection(df1, df2)
# --> 141 dfsym = _overlay_symmetric_diff(df1, df2)
#     142 dfunion = pd.concat([dfinter, dfsym], ignore_index=True, sort=False)
#     143 # keep geometry column last
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\geopandas\tools\overlay.py:112, in _overlay_symmetric_diff(df1, df2)
#     108 """
#     109 Overlay Symmetric Difference operation used in overlay function
#     110 """
#     111 dfdiff1 = _overlay_difference(df1, df2)
# --> 112 dfdiff2 = _overlay_difference(df2, df1)
#     113 dfdiff1["__idx1"] = range(len(dfdiff1))
#     114 dfdiff2["__idx2"] = range(len(dfdiff2))
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\geopandas\tools\overlay.py:94, in _overlay_difference(df1, df2)
#      92 new_g = []
#      93 for geom, neighbours in zip(df1.geometry, sidx):
# ---> 94     new = reduce(
#      95         lambda x, y: x.difference(y), [geom] + list(df2.geometry.iloc[neighbours])
#      96     )
#      97     new_g.append(new)
#      98 differences = GeoSeries(new_g, index=df1.index, crs=df1.crs)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\geopandas\tools\overlay.py:95, in _overlay_difference.<locals>.<lambda>(x, y)
#      92 new_g = []
#      93 for geom, neighbours in zip(df1.geometry, sidx):
#      94     new = reduce(
# ---> 95         lambda x, y: x.difference(y), [geom] + list(df2.geometry.iloc[neighbours])
#      96     )
#      97     new_g.append(new)
#      98 differences = GeoSeries(new_g, index=df1.index, crs=df1.crs)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\shapely\geometry\base.py:591, in BaseGeometry.difference(self, other, grid_size)
#     585 def difference(self, other, grid_size=None):
#     586     """
#     587     Returns the difference of the geometries.
#     588
#     589     Refer to `shapely.difference` for full documentation.
#     590     """
# --> 591     return shapely.difference(self, other, grid_size=grid_size)
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\YLuo\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\shapely\set_operations.py:76, in difference(a, b, grid_size, **kwargs)
#      72         raise ValueError("grid_size parameter only accepts scalar values")
#      74     return lib.difference_prec(a, b, grid_size, **kwargs)
# ---> 76 return lib.difference(a, b, **kwargs)
#
# GEOSException: TopologyException: found non-noded intersection between LINESTRING (1.02004e+06 267373, 1.02004e+06 267373) and LINESTRING (1.02004e+06 267373, 1.02004e+06 267373) at 1020038.4706394268 267372.78359945898

# %% [markdown]
# ## 9. Winter Weather

# %%
if (run_all or run_WIW):
    
    print("{} Pre-processing WIW death loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_WIW_death_loss_1.py

    print("{} Pre-processing WIW injury loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_WIW_injury_loss_1.py

    print("{} Pre-processing WIW snow removal loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_WIW_snow_loss_1.py

    print("{} Pre-processing WIW tree servicing loss.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/DATA_PROCESSING/ESL_WIW_tree_loss_1.py
# Out:
# 15:18 Pre-processing WIW death loss.....
# Finished calculating WIW death loss.
# 15:18 Pre-processing WIW injury loss.....
# Finished calculating WIW injury loss.
# 15:18 Pre-processing WIW snow removal loss.....
# Index(['BCT_txt', 'Critical_Route_Count', 'Critical_Route_Length'], dtype='object')
# Index(['ctlabel', 'borocode', 'boroname', 'ct2020', 'boroct2020', 'cdeligibil',
#        'ntaname', 'nta2020', 'cdta2020', 'cdtaname', 'geoid', 'shape_leng',
#        'shape_area', 'geometry', 'BCT_txt'],
#       dtype='object')
# Finished calculating  ESL WIW snow removal loss.
# 15:18 Pre-processing WIW tree servicing loss.....
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\VSCode\URI_Calculator_v1_1_TEMPLATE_v4\URI_Calculator_v1_1_TEMPLATE\4_CODE\URI\DATA_PROCESSING\ESL_WIW_tree_loss_1.py:52
#      50 for i, idx in enumerate(df_Events.index):
#      51     start_date = df_Events.at[idx, 'StartDate']
# ---> 52     end_date = df_Events.at[idx, 'EndDate'] + datetime.timedelta(days=service_buffer)
#      53     df_tree.loc[((df_tree.DateInitiated >= start_date) & (df_tree.DateInitiated <= end_date)), 'Is_Event'] = 1
#      55 #%%
#
# TypeError: unsupported type for timedelta days component: params

# %%
print("Complete".format(datetime.datetime.now().strftime("%H:%M")))
# Out:
# Complete

# %% [markdown]
# ## 10. Normalize Data

# %%
if (run_all or run_normalize):
    
    print("{} Pre-processing Normalization Factors.....".format(datetime.datetime.now().strftime("%H:%M")))
    # %run ./4_CODE/URI/MISC/write_normalization_vars_1.py
# Out:
# 15:19 Pre-processing Normalization Factors.....
