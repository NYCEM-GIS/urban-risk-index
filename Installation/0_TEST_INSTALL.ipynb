# %% [markdown]
# ## Test Import Packages

# %%
#test installations
import geopandas
import rtree
import scipy
import sklearn
import matplotlib.pyplot as plt
import requests
import rasterio
import rasterstats
import census
import us
print("All packages successfully loaded!")
# Out:
# All packages successfully loaded!

# %%
# !pip install geopandas==0.7.0
import geopandas

# %% [markdown]
# ## Test Plot Shapefile

# %%
path_shapefile = './shapefile/URI_ALL_Tract.shp'
gdf_shp = geopandas.read_file(path_shapefile)

#test plot
fig = plt.figure()
ax = fig.add_subplot(111)
gdf_shp.plot(ax=ax, column='ALLU_SN')
plt.title("This is a map of NYC")
ax.axis('off')

print("GIS working!")
# Out:
# c:\Users\HSprague\vscode\URI_Calculator_v1_1_TEMPLATE\.venv\Lib\site-packages\pyogrio\raw.py:196: RuntimeWarning: ./shapefile/URI_ALL_Tract.shp contains polygon(s) with rings with invalid winding order. Autocorrecting them, but that shapefile should be corrected using ogr2ogr for example.
#   return ogr_read(
# GIS working!
