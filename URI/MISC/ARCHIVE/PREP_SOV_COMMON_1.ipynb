# %% [markdown]
# ## 1. Calculate SOV
# Load  the CDC social vulnerability index.

# %%
import URI.MISC.params_1 as params
import URI.MISC.utils_1 as utils
import matplotlib.pyplot as plt
import os
utils.set_home()

#calculate heat events per year
script_name = '.\\4_CODE\DATA_PROCESSING\SOV_calculation_1.py'
exec(open(script_name).read())
# Out:
# Finished calculating SOV score.

# %% [markdown]
# Plot the raw social vulnerability index value.

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
gdf_tract.plot(ax=ax, column = 'RPL_THEMES_ADJ', legend=True )
plt.axis('off')
plt.title('CDC Social Vulnerability Index')
# Out:
# Text(0.5, 1.0, 'CDC Social Vulnerability Index')

# %% [markdown]
# Plot the adjusted score on 1 (low) to 5 (high) scale.

# %%
fig = plt.figure(figsize=(10, 5))
ax = fig.add_subplot(111)
gdf_tract.plot(ax=ax, column = 'Score', legend=True )
plt.axis('off')
plt.title('CDC Social Vulnerability Index Score')
# Out:
# Text(0.5, 1.0, 'CDC Social Vulnerability Index Score')
