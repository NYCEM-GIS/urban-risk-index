# %% [markdown]
# # RCA Preprocessing

# %% [markdown]
# ## 1. Community Capital

# %%
from MISC import utils_1 as utils
utils.set_home()
import warnings
import datetime
warnings.filterwarnings(action='once')

print("{} Pre-processing Community Infrastructure.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_CC_CI_read_1.py

print("{} Pre-processing Education and Outreach.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_CC_EO_read_1.py

print("{} Pre-process Place Attachment.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_CC_PA_read_1.py

print("{} Pre-process Political Engagement.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_CC_PE_read_1.py
# Out:
# 00:24 Pre-processing Community Infrastructure.....
# Finished calculating RCA factor: Community Infrastructure.
# 00:41 Pre-processing Education and Outreach.....
# Finished calculating RCA factor: Education and Outreach.
# 00:41 Pre-process Place Attachment.....
# Finished calculating RCA factor: Place attachment.
# 00:41 Pre-process Political Engagement.....
# Finished calculating RCA factor: Political engagement.
# WARNING:fiona._env:Value 196629759.602159619 of field area_ft2 of feature 1859 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225036.844661877 of field area_ft2 of feature 2141 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105951090.0664915 of field area_ft2 of feature 2156 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023060004 of field BBL of feature 0 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046580015 of field BBL of feature 1 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023530057 of field BBL of feature 2 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1008870087 of field BBL of feature 3 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1007800009 of field BBL of feature 4 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5000050065 of field BBL of feature 5 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027400100 of field BBL of feature 6 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014370008 of field BBL of feature 7 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2037510001 of field BBL of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029060089 of field BBL of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023070054 of field BBL of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027240186 of field BBL of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2026620044 of field BBL of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029550001 of field BBL of feature 13 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2025170001 of field BBL of feature 14 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029270013 of field BBL of feature 15 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2043190045 of field BBL of feature 16 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2032940047 of field BBL of feature 17 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2032780085 of field BBL of feature 18 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023810029 of field BBL of feature 19 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2048370036 of field BBL of feature 20 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022670044 of field BBL of feature 21 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2025510058 of field BBL of feature 22 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046540070 of field BBL of feature 23 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2039360032 of field BBL of feature 24 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022850075 of field BBL of feature 25 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012250023 of field BBL of feature 26 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4158910021 of field BBL of feature 27 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3015040007 of field BBL of feature 28 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3036860034 of field BBL of feature 29 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4160400024 of field BBL of feature 30 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4098360015 of field BBL of feature 31 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1022220041 of field BBL of feature 32 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4130180036 of field BBL of feature 33 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4017530011 of field BBL of feature 34 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017540024 of field BBL of feature 35 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017870001 of field BBL of feature 36 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4116610011 of field BBL of feature 37 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3011770038 of field BBL of feature 38 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5005330036 of field BBL of feature 39 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3031970034 of field BBL of feature 40 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3019730028 of field BBL of feature 41 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3036120024 of field BBL of feature 42 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3005650001 of field BBL of feature 43 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014360006 of field BBL of feature 44 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3015670008 of field BBL of feature 45 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2026910012 of field BBL of feature 46 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017290052 of field BBL of feature 47 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1020450075 of field BBL of feature 48 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012780058 of field BBL of feature 49 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3007550045 of field BBL of feature 50 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2031330021 of field BBL of feature 51 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2035960001 of field BBL of feature 52 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3049960001 of field BBL of feature 53 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012310016 of field BBL of feature 54 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022680006 of field BBL of feature 55 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2033200001 of field BBL of feature 56 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014460036 of field BBL of feature 57 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027050018 of field BBL of feature 58 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3064030001 of field BBL of feature 59 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3047110012 of field BBL of feature 60 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1002850021 of field BBL of feature 61 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2034960037 of field BBL of feature 62 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1022370018 of field BBL of feature 63 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3048920003 of field BBL of feature 64 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3051020073 of field BBL of feature 65 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017260032 of field BBL of feature 66 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2038750001 of field BBL of feature 67 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046190001 of field BBL of feature 68 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3016780084 of field BBL of feature 69 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3020460052 of field BBL of feature 70 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1016650025 of field BBL of feature 71 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2026900080 of field BBL of feature 72 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1021320007 of field BBL of feature 73 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4158040018 of field BBL of feature 74 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022980101 of field BBL of feature 75 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3053820001 of field BBL of feature 76 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155370040 of field BBL of feature 77 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1008870087 of field BBL of feature 78 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3031530031 of field BBL of feature 79 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2030610001 of field BBL of feature 80 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3034260009 of field BBL of feature 81 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027200034 of field BBL of feature 82 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3033350041 of field BBL of feature 83 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013710044 of field BBL of feature 84 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3080070012 of field BBL of feature 85 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3051480062 of field BBL of feature 86 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4107890114 of field BBL of feature 87 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1004777501 of field BBL of feature 88 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1000420031 of field BBL of feature 89 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3024180040 of field BBL of feature 90 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5009550100 of field BBL of feature 91 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3003990006 of field BBL of feature 92 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017610066 of field BBL of feature 93 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013570051 of field BBL of feature 94 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3027900029 of field BBL of feature 95 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4019180097 of field BBL of feature 96 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4121610042 of field BBL of feature 97 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4097680044 of field BBL of feature 98 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046280043 of field BBL of feature 99 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3041240045 of field BBL of feature 100 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1018430041 of field BBL of feature 101 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013300034 of field BBL of feature 102 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3032150031 of field BBL of feature 103 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023690018 of field BBL of feature 104 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3018840070 of field BBL of feature 105 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5010370060 of field BBL of feature 106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046490001 of field BBL of feature 107 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017860049 of field BBL of feature 108 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3009380026 of field BBL of feature 109 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4117580046 of field BBL of feature 110 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3030510018 of field BBL of feature 111 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022780038 of field BBL of feature 112 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4010560010 of field BBL of feature 113 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3057340024 of field BBL of feature 114 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2034550143 of field BBL of feature 115 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2030710001 of field BBL of feature 116 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155010050 of field BBL of feature 117 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2031240069 of field BBL of feature 118 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4005100006 of field BBL of feature 119 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017870036 of field BBL of feature 120 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017710044 of field BBL of feature 121 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3051640022 of field BBL of feature 122 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014800019 of field BBL of feature 123 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012370043 of field BBL of feature 124 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013910066 of field BBL of feature 125 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3035830001 of field BBL of feature 126 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4120480085 of field BBL of feature 127 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4110720005 of field BBL of feature 128 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4035080009 of field BBL of feature 129 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4049780046 of field BBL of feature 130 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4004260001 of field BBL of feature 131 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017220069 of field BBL of feature 132 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027060028 of field BBL of feature 133 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029080040 of field BBL of feature 134 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2049470047 of field BBL of feature 135 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028630054 of field BBL of feature 136 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2034960046 of field BBL of feature 137 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3046050040 of field BBL of feature 138 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012400063 of field BBL of feature 139 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3043060058 of field BBL of feature 140 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5012250043 of field BBL of feature 141 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5000230070 of field BBL of feature 142 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5008260015 of field BBL of feature 143 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1011200044 of field BBL of feature 144 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3045920024 of field BBL of feature 145 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3040080013 of field BBL of feature 146 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012600027 of field BBL of feature 147 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017500005 of field BBL of feature 148 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4095590040 of field BBL of feature 149 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3018460047 of field BBL of feature 150 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3016860040 of field BBL of feature 151 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3050570026 of field BBL of feature 152 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3036130028 of field BBL of feature 153 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013740006 of field BBL of feature 154 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012380044 of field BBL of feature 155 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3074640001 of field BBL of feature 156 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3086767501 of field BBL of feature 157 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3063780019 of field BBL of feature 158 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4016880002 of field BBL of feature 159 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4134850015 of field BBL of feature 160 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4002330001 of field BBL of feature 161 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4035890001 of field BBL of feature 162 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4101250010 of field BBL of feature 163 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5005800034 of field BBL of feature 164 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2024220035 of field BBL of feature 165 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1008170080 of field BBL of feature 166 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1007800026 of field BBL of feature 167 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1005920069 of field BBL of feature 168 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017360007 of field BBL of feature 169 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1014330127 of field BBL of feature 170 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1018650001 of field BBL of feature 171 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1003910007 of field BBL of feature 172 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1021420133 of field BBL of feature 173 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1012347502 of field BBL of feature 174 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1018680124 of field BBL of feature 175 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1016140066 of field BBL of feature 176 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1016140066 of field BBL of feature 177 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4102080001 of field BBL of feature 178 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4121810030 of field BBL of feature 179 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4105710021 of field BBL of feature 180 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4017430020 of field BBL of feature 181 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4011360048 of field BBL of feature 182 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4014470035 of field BBL of feature 183 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4017220005 of field BBL of feature 184 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4005420008 of field BBL of feature 185 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155450023 of field BBL of feature 186 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4097720046 of field BBL of feature 187 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4009090001 of field BBL of feature 188 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4111130023 of field BBL of feature 189 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4101550029 of field BBL of feature 190 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4097607501 of field BBL of feature 191 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4017120019 of field BBL of feature 192 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4007240014 of field BBL of feature 193 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4141700001 of field BBL of feature 194 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4033477501 of field BBL of feature 195 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4103940007 of field BBL of feature 196 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4120280053 of field BBL of feature 197 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4007080040 of field BBL of feature 198 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4097600013 of field BBL of feature 199 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4036280026 of field BBL of feature 200 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4133030063 of field BBL of feature 201 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4124490004 of field BBL of feature 202 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155640079 of field BBL of feature 203 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4050440044 of field BBL of feature 204 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4067130041 of field BBL of feature 205 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4116090018 of field BBL of feature 206 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5010330028 of field BBL of feature 207 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5069980024 of field BBL of feature 208 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5005110003 of field BBL of feature 209 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5010420023 of field BBL of feature 210 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5005250021 of field BBL of feature 211 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5005170030 of field BBL of feature 212 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013840016 of field BBL of feature 213 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022860006 of field BBL of feature 214 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1021170031 of field BBL of feature 215 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1019830011 of field BBL of feature 216 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4124480025 of field BBL of feature 217 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3018510039 of field BBL of feature 218 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2024660026 of field BBL of feature 219 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1014980047 of field BBL of feature 220 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155600012 of field BBL of feature 221 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014267501 of field BBL of feature 222 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012840014 of field BBL of feature 223 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014510006 of field BBL of feature 224 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3044310070 of field BBL of feature 225 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1007370043 of field BBL of feature 226 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1004200047 of field BBL of feature 227 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1010360037 of field BBL of feature 228 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1022010021 of field BBL of feature 229 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3018330038 of field BBL of feature 230 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3035100033 of field BBL of feature 231 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5010890036 of field BBL of feature 232 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4101900025 of field BBL of feature 233 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1018960020 of field BBL of feature 234 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3041280044 of field BBL of feature 235 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1006090020 of field BBL of feature 236 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1020600001 of field BBL of feature 237 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2047590048 of field BBL of feature 238 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028280037 of field BBL of feature 239 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3070200039 of field BBL of feature 240 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028410078 of field BBL of feature 241 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4098950001 of field BBL of feature 242 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3016560005 of field BBL of feature 243 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2031730036 of field BBL of feature 244 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3019480035 of field BBL of feature 245 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017460002 of field BBL of feature 246 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3018510073 of field BBL of feature 247 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4097580047 of field BBL of feature 248 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012720020 of field BBL of feature 249 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017550032 of field BBL of feature 250 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2031570014 of field BBL of feature 251 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3050430049 of field BBL of feature 252 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029920065 of field BBL of feature 253 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4097930086 of field BBL of feature 254 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1007290001 of field BBL of feature 255 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3009410030 of field BBL of feature 256 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013820020 of field BBL of feature 257 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017500030 of field BBL of feature 258 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1005640032 of field BBL of feature 259 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4129560012 of field BBL of feature 260 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1010560022 of field BBL of feature 261 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1016450040 of field BBL of feature 262 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2037780034 of field BBL of feature 263 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2039150016 of field BBL of feature 264 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5031680039 of field BBL of feature 265 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023680038 of field BBL of feature 266 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3070230109 of field BBL of feature 267 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3076180028 of field BBL of feature 268 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3034440022 of field BBL of feature 269 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022740011 of field BBL of feature 270 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3062470030 of field BBL of feature 271 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017110048 of field BBL of feature 272 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4090660031 of field BBL of feature 273 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4033310066 of field BBL of feature 274 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2030590036 of field BBL of feature 275 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1020580032 of field BBL of feature 276 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3016220060 of field BBL of feature 277 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1021070012 of field BBL of feature 278 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2030310007 of field BBL of feature 279 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017880008 of field BBL of feature 280 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3017550046 of field BBL of feature 281 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1012340061 of field BBL of feature 282 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023740035 of field BBL of feature 283 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046310067 of field BBL of feature 284 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1018250020 of field BBL of feature 285 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1004050041 of field BBL of feature 286 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4009100023 of field BBL of feature 287 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3003580012 of field BBL of feature 288 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3056070019 of field BBL of feature 289 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2026110001 of field BBL of feature 290 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027200052 of field BBL of feature 291 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155450019 of field BBL of feature 292 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4021760001 of field BBL of feature 293 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3050890064 of field BBL of feature 294 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3015420051 of field BBL of feature 295 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1006180040 of field BBL of feature 296 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027870001 of field BBL of feature 297 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3018030070 of field BBL of feature 298 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1016660024 of field BBL of feature 299 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3046300045 of field BBL of feature 300 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4098130001 of field BBL of feature 301 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1011310016 of field BBL of feature 302 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4108200023 of field BBL of feature 303 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4158330041 of field BBL of feature 304 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2030610031 of field BBL of feature 305 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014250001 of field BBL of feature 306 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1019050029 of field BBL of feature 307 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2027940035 of field BBL of feature 308 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3033170041 of field BBL of feature 309 not successfully written. Possibly due to too larger number with respect to field width
# ...
# WARNING:fiona._env:Value 3014920015 of field BBL of feature 2789 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2030600008 of field BBL of feature 2790 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017220019 of field BBL of feature 2791 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4119460119 of field BBL of feature 2792 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2046630009 of field BBL of feature 2793 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4129560036 of field BBL of feature 2794 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2022880095 of field BBL of feature 2795 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4095280035 of field BBL of feature 2796 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4030880001 of field BBL of feature 2797 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4096890004 of field BBL of feature 2798 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3028320001 of field BBL of feature 2799 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2024720034 of field BBL of feature 2800 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2048600048 of field BBL of feature 2801 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3036830001 of field BBL of feature 2802 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3012130005 of field BBL of feature 2803 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029730016 of field BBL of feature 2804 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4030860007 of field BBL of feature 2805 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3055940042 of field BBL of feature 2806 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3065310016 of field BBL of feature 2807 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3054350011 of field BBL of feature 2808 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1021140058 of field BBL of feature 2809 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4106230001 of field BBL of feature 2810 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4095500001 of field BBL of feature 2811 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2023940030 of field BBL of feature 2812 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2049750001 of field BBL of feature 2813 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3049780001 of field BBL of feature 2814 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2031690001 of field BBL of feature 2815 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028770522 of field BBL of feature 2816 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3087600060 of field BBL of feature 2817 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3040530020 of field BBL of feature 2818 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4102820125 of field BBL of feature 2819 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028650064 of field BBL of feature 2820 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3014680012 of field BBL of feature 2821 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028970051 of field BBL of feature 2822 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4089140022 of field BBL of feature 2823 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4006990041 of field BBL of feature 2824 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4050220001 of field BBL of feature 2825 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3078100037 of field BBL of feature 2826 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1018710029 of field BBL of feature 2827 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3068050045 of field BBL of feature 2828 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1019330026 of field BBL of feature 2829 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4125880044 of field BBL of feature 2830 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3013440175 of field BBL of feature 2831 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4131550006 of field BBL of feature 2832 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4019770004 of field BBL of feature 2833 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3050230009 of field BBL of feature 2834 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4004720640 of field BBL of feature 2835 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2028630028 of field BBL of feature 2836 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2038670032 of field BBL of feature 2837 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2025290081 of field BBL of feature 2838 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2033340016 of field BBL of feature 2839 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3047030007 of field BBL of feature 2840 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2026650056 of field BBL of feature 2841 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4101290003 of field BBL of feature 2842 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1019310027 of field BBL of feature 2843 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2059140315 of field BBL of feature 2844 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4021590002 of field BBL of feature 2845 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1008280009 of field BBL of feature 2846 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 4155270015 of field BBL of feature 2847 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1005450026 of field BBL of feature 2848 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1012330011 of field BBL of feature 2849 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 2029180006 of field BBL of feature 2850 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3049150063 of field BBL of feature 2851 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 5076640001 of field BBL of feature 2852 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1010330006 of field BBL of feature 2853 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 3034870018 of field BBL of feature 2854 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 1017830012 of field BBL of feature 2855 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Normalized/laundered field name: 'Fraction_Covered' to 'Fraction_C'
# WARNING:fiona._env:Value 196629759.602159619 of field area_ft2 of feature 1859 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225036.844661877 of field area_ft2 of feature 2141 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105951090.0664915 of field area_ft2 of feature 2156 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196629759.602159619 of field area_ft2 of feature 1859 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225036.844661877 of field area_ft2 of feature 2141 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105951090.0664915 of field area_ft2 of feature 2156 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:Normalized/laundered field name: 'pop_older_1yr' to 'pop_older_'
# WARNING:fiona._env:Normalized/laundered field name: 'same_house_1yr_ago' to 'same_house'
# WARNING:fiona._env:Normalized/laundered field name: 'diff_house_same_city_1yr_ago' to 'diff_house'
# WARNING:fiona._env:Normalized/laundered field name: 'percent_living_in_NY_over_1yr' to 'percent_li'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# WARNING:fiona._env:Normalized/laundered field name: 'FIPS_CT_txt' to 'FIPS_CT_tx'
# WARNING:fiona._env:Normalized/laundered field name: 'Avg. Participation Score 2018' to 'Avg. Parti'

# %% [markdown]
# ## 2. Mitigation Landscape

# %%
print("{} Pre-processing Mitigation Investments.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_ML_MI_read_1.py

print("{} Pre-processing Vegetative Cover.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_ML_VC_read_1.py

print("{} Pre-process Parks with Water Features.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_ML_PWF_read_1.py

print("{} Pre-process Presence of Natural Shoreline.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_ML_NS_read_1.py

print("{} Pre-process Presence of Green Infrastructure.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_ML_GI_read_1.py
# Out:
# 00:42 Pre-processing Mitigation Investments.....
# Calculating investment per hazard.....Done
# Finished calculating RCA factor: Mitigation Investment.
# 00:42 Pre-processing Vegetative Cover.....
# Finished calculating RCA factor: Vegetative Cover.
# 01:33 Pre-process Parks with Water Features.....
# Calculating...Done
# Finished calculating RCA factor: park water feature.
# 01:37 Pre-process Presence of Natural Shoreline.....
# Finished calculating RCA factor: Place attachment.
# 01:51 Pre-process Presence of Green Infrastructure.....
# Finished calculating RCA factor: Green Infrastructure.
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\sklearn\cluster\_kmeans.py:1105: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# WARNING:fiona._env:Normalized/laundered field name: 'Coastal Erosion' to 'Coastal Er'
# WARNING:fiona._env:Normalized/laundered field name: 'Coastal Storms' to 'Coastal St'
# WARNING:fiona._env:Normalized/laundered field name: 'Earthquakes' to 'Earthquake'
# WARNING:fiona._env:Normalized/laundered field name: 'Extreme Heat' to 'Extreme He'
# WARNING:fiona._env:Normalized/laundered field name: 'Winter Weather' to 'Winter Wea'
# WARNING:fiona._env:Normalized/laundered field name: 'Winter Storms' to 'Winter Sto'
# WARNING:fiona._env:Normalized/laundered field name: 'Disease Outbreaks' to 'Disease Ou'
# WARNING:fiona._env:Normalized/laundered field name: 'Cyber Threats' to 'Cyber Thre'
# WARNING:fiona._env:Value 127014445.160164207 of field Coastal St of feature 288 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 125000000 of field Extreme He of feature 288 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 125000000 of field EXH of feature 288 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 127014445.160164207 of field CST of feature 288 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 382799875.19159466 of field Flooding of feature 1111 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 382799875.19159466 of field FLD of feature 1111 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 123783589.551764861 of field Flooding of feature 1125 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 123783589.551764861 of field FLD of feature 1125 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 354245431.179775298 of field Flooding of feature 1387 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 354245431.179775298 of field FLD of feature 1387 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196629759.602159619 of field area_ft2 of feature 1859 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225036.844661877 of field area_ft2 of feature 2141 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105951090.0664915 of field area_ft2 of feature 2156 not successfully written. Possibly due to too larger number with respect to field width
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# T:\CCSI\TECH\2020_NYCURI\Working_Dano\4_CODE\MISC\utils_1.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_gdf_union.dropna(subset=[column_name], inplace=True)
# WARNING:fiona._env:Normalized/laundered field name: 'Pct_Veg_Cover_Tract' to 'Pct_Veg_Co'
# WARNING:fiona._env:Normalized/laundered field name: 'Fraction_Covered' to 'Fraction_C'
# WARNING:fiona._env:Value 196629759.602159619 of field area_ft2 of feature 1859 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225036.844661877 of field area_ft2 of feature 2141 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105951090.0664915 of field area_ft2 of feature 2156 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width

# %% [markdown]
# ## 3. Response Capacity

# %%
print("{} Pre-processing Emergency Medical Access.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_EMA_read_1.py

print("{} Pre-processing Walkability....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_WA_read_1.py

print("{} Pre-process Parks with Bikability.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_BI_read_1.py

print("{} Pre-process Transit.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_TR_read_1.py

print("{} Pre-process Shelter Capacity.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_SC_read_1.py

print("{} Pre-process Evacuation Potential.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_EP_read_1.py

print("{} Pre-process Air Conditioning in the Home.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_AC_read_1.py

print("{} Pre-process Institutional Experience.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_INE_read_1.py

print("{} Pre-process Cooling Centers.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RC_CC_read_1.py
# Out:
# 01:51 Pre-processing Emergency Medical Access.....
# Finished calculating RCA factor: emergency capacity.
# 01:52 Pre-processing Walkability....
# Finished calculating RCA factor: walkability.
# 01:52 Pre-process Parks with Bikability.....
# Finished calculating RCA factor: bikability.
# 01:52 Pre-process Transit.....
# Finished calculating RCA factor: transit score.
# 01:52 Pre-process Shelter Capacity.....
# Finished calculating RCA factor: shelter capacity
# 01:56 Pre-process Evacuation Potential.....
# Finished calculating RCA factor: emergency capacity.
# 01:56 Pre-process Air Conditioning in the Home.....
# Warning: AC percent is 103.54285714285714, greater than 100 with a population of 1120.0.
# Warning: AC percent is 285.59951223082004, greater than 100 with a population of 39.0.
# Finished calculating RC factor AC.
# 01:57 Pre-process Institutional Experience.....
# Finished calculating RCA factor: Institutional Experience.
# 01:57 Pre-process Cooling Centers.....
# Calculating.
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# Finished calculating RCA factor: Cooling Centers.
# WARNING:fiona._env:Normalized/laundered field name: 'Distance_HYPO' to 'Distance_H'
# WARNING:fiona._env:Normalized/laundered field name: 'Distance_TRAUMA' to 'Distance_T'
# WARNING:fiona._env:Normalized/laundered field name: 'Distance_RECEIVING' to 'Distance_R'
# WARNING:fiona._env:Normalized/laundered field name: 'transitscore' to 'transitsco'
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# WARNING:fiona._env:Normalized/laundered field name: 'pop_2010_density' to 'pop_2010_d'
# WARNING:fiona._env:Normalized/laundered field name: 'LT_capacity_count' to 'LT_capacit'
# WARNING:fiona._env:Normalized/laundered field name: 'capacity_allocation_per_1000' to 'capacity_a'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105948017.81157124 of field area_ft2 of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225340.491160423 of field area_ft2 of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149285.554758549 of field area_ft2 of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:Normalized/laundered field name: 'Distance_Center' to 'Distance_C'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# T:\CCSI\TECH\2020_NYCURI\Working_Dano\4_CODE\MISC\utils_1.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   this_gdf_union.dropna(subset=[column_name], inplace=True)
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# WARNING:fiona._env:Normalized/laundered field name: 'ac_per_post' to 'ac_per_pos'
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_EXH' to 'EOC_Durati'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_WIW' to 'EOC_Dura_1'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_CST' to 'EOC_Dura_2'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_CER' to 'EOC_Dura_3'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_CYB' to 'EOC_Dura_4'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_RES' to 'EOC_Dura_5'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_EMG' to 'EOC_Dura_6'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_CRN' to 'EOC_Dura_7'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_HIW' to 'EOC_Dura_8'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_ERQ' to 'EOC_Dura_9'
# WARNING:fiona._env:Normalized/laundered field name: 'EOC_Duration_days_FLD' to 'EOC_Dura10'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:Normalized/laundered field name: 'Fraction_Covered' to 'Fraction_C'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105948017.81157124 of field area_ft2 of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225340.491160423 of field area_ft2 of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149285.554758549 of field area_ft2 of feature 2106 not successfully written. Possibly due to too larger number with respect to field width

# %% [markdown]
# ## 4. Recovery Resources

# %%
print("{} Pre-processing Median Household Income.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RR_MHI_read_1.py

print("{} Pre-processing Health Insurance Coverage....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RR_HIC_read_1.py

print("{} Pre-process Income Inequality.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RR_IE_read_1.py

print("{} Pre-process Flood Insurance Coverage.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RR_FP_read_1.py

print("{} Pre-process Home Ownership.....".format(datetime.datetime.now().strftime("%H:%M")))
# %run ./4_CODE/DATA_PROCESSING/RCA_RR_HO_read_1.py
# Out:
# 02:00 Pre-processing Median Household Income.....
# Finished calculating RCA factor: median household income.
# 02:01 Pre-processing Health Insurance Coverage....
# Finished calculating RCA factor: percent insured.
# 02:01 Pre-process Income Inequality.....
# Finished calculating RCA factor: Gini Coefficient.
# 02:01 Pre-process Flood Insurance Coverage.....
# Begin Join
# Warning: more policies than buildings with 37.0 policies and 29.0 buildings.
# Finished calculating RR factor FP.
# 02:05 Pre-process Home Ownership.....
# Finished calculating RCA factor: Home ownership.
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# WARNING:fiona._env:Normalized/laundered field name: 'FIPS_CT_txt' to 'FIPS_CT_tx'
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\xlrd\xlsx.py:266: PendingDeprecationWarning: This method will be removed in future versions.  Use 'tree.iter()' or 'list(tree.iter())' instead.
#   for elem in self.tree.iter() if Element_has_iter else self.tree.getiterator():
# WARNING:fiona._env:Normalized/laundered field name: 'FIPS_CT_txt' to 'FIPS_CT_tx'
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:Value -666666666 of field gini of feature 589 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 624 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 761 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 878 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 885 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 982 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1036 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1195 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1296 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1302 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1313 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1360 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1371 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1375 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1409 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1422 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1494 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1497 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1534 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1537 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1592 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1602 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1637 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1671 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1675 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1774 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1791 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1822 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1874 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1888 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1903 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1905 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1908 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1909 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1910 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1943 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1956 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1961 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1968 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1975 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 1998 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2014 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2023 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2027 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2028 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2095 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2108 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2109 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2121 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2133 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value -666666666 of field gini of feature 2161 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# c:\programdata\anaconda3\envs\geo-env\lib\site-packages\numpy\lib\function_base.py:2167: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)
# WARNING:fiona._env:Normalized/laundered field name: 'Building_Count' to 'Building_C'
# WARNING:fiona._env:Normalized/laundered field name: 'Policy_Count' to 'Policy_Cou'
# WARNING:fiona._env:Normalized/laundered field name: 'Percent_Coverage' to 'Percent_Co'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1503 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1505 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1507 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1592 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1683 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 1876 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2107 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:organizePolygons() received an unexpected geometry.  Either a polygon with interior rings, or a polygon with less than 4 points, or a non-Polygon geometry.  Return arguments as a collection.
# WARNING:fiona._env:Geometry of polygon of fid 2134 cannot be translated to Simple Geometry. All polygons will be contained in a multipolygon.
# WARNING:fiona._env:Normalized/laundered field name: 'percent_home_owner' to 'percent_ho'
# WARNING:fiona._env:Value 105947920.671000004 of field Shape_Area of feature 2043 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 116225407.056999996 of field Shape_Area of feature 2074 not successfully written. Possibly due to too larger number with respect to field width
# WARNING:fiona._env:Value 196149385.823000014 of field Shape_Area of feature 2106 not successfully written. Possibly due to too larger number with respect to field width

# %%
print("{} Complete".format(datetime.datetime.now().strftime("%H:%M")))
# Out:
# 02:05 Complete
